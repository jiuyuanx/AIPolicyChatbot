# %%
# !pip install -q  torch peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 accelerate  datasets #xformers
import transformers
import torch
import datasets
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)
from peft import LoraConfig
from trl import SFTTrainer
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ## **Create HuggingFace dataset from json**

# %%
import json
json_file_path = 'Policy_QA.json'

# Reading the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# %%
import pandas as pd
data_list = [{'input': item['input'], 'output': item['output']} for item in data.values()]
df = pd.DataFrame(data_list)
df
# Out:
#                                                 input  \
# 0   What are the twin goals of Singapore’s NAIS 2....
# 1   To achieve the vision and goals, Singapore wil...
# 2   What are the 15 Actions that Singapore will un...
# 3   How will Singapore contribute to international...
# 4   How will Singapore intensify the promotion of ...
# ..                                                ...
# 89  What is the World Bank's Policy on Access to I...
# 90  Why does the World Bank restrict access to cer...
# 91  How can someone request information from the W...
# 92  What are the types of information classified u...
# 93  How does the World Bank handle declassificatio...
#
#                                                output
# 0   One is excellence: Singapore will selectively ...
# 1   System 1: Activity Drivers (Enablers: Industry...
# 2   (1) Anchor new AI Centres of Excellence (CoEs)...
# 3   (1) Anchoring key bilateral relationships with...
# 4   (1) Make available tools that enterprises can ...
# ..                                                ...
# 89  The policy outlines the World Bank's commitmen...
# 90  The policy includes exceptions to protect sens...
# 91  Individuals can request information through th...
# 92  Information is classified into categories such...
# 93  The policy outlines a schedule for declassifyi...
#
# [94 rows x 2 columns]

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import Dataset, DatasetDict, load_dataset
# Create a Dataset object from your data
qa_dataset = Dataset.from_pandas(df)

# Optionally, split your dataset into training and testing sets
qa_dataset = DatasetDict({
    'train': qa_dataset.train_test_split(test_size=0.2)['train'],
    'test': qa_dataset.train_test_split(test_size=0.2)['test']
})

# Push your dataset to the Hugging Face Hub
qa_dataset.push_to_hub("jiuyuan/policy_AI")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/jiuyuan/policy_AI/commit/ba692e249e579e1cf9e99203aecda940632be9eb', commit_message='Upload dataset', commit_description='', oid='ba692e249e579e1cf9e99203aecda940632be9eb', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## **Load dataset from HuggingFace**

# %%
# Dataset
data_name = "jiuyuan/policy_AI"
training_data = load_dataset(data_name, split="train")
test_data = load_dataset(data_name, split="test")
# Out:
# Downloading readme:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/31.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/8.78k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/75 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/19 [00:00<?, ? examples/s]

# %%
training_data
# Out:
# Dataset({
#     features: ['input', 'output'],
#     num_rows: 75
# })

# %%
# Model and tokenizer names
base_model_name = "NousResearch/Llama-2-7b-chat-hf"
refined_model = "llama-2-7b-policyAI"

# Tokenizer
llama_tokenizer = AutoTokenizer.from_pretrained(base_model_name, trust_remote_code=True)
llama_tokenizer.pad_token = llama_tokenizer.eos_token
llama_tokenizer.padding_side = "right"  # Fix for fp16

# Quantization Config
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=False
)

# Model
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
base_model.config.use_cache = False
base_model.config.pretraining_tp = 1
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]

# %%
def formatting_prompts_func(example):
    output_texts = []
    for i in range(len(example['input'])):
        text = f"### Question: {example['input'][i]}\n ### Answer: {example['output'][i]}</s>"
        output_texts.append(text)
    return output_texts

# %% [markdown]
# ## **Fine tune**

# %%
# LoRA Config
peft_parameters = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=8,#rank
    bias="none",
    task_type="CAUSAL_LM"
)

batch_size_multiplier = 2
# Training Params
train_params = TrainingArguments(
    output_dir="./results_modified",
    evaluation_strategy = "epoch",
    num_train_epochs=30,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1*batch_size_multiplier,
    optim="paged_adamw_32bit",
    save_steps=100,
    logging_steps=20//batch_size_multiplier,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
    report_to="tensorboard"
)

# Trainer
fine_tuning = SFTTrainer(
    model=base_model,
    train_dataset=training_data,
    eval_dataset = test_data,
    formatting_func=formatting_prompts_func, #hereeee
    peft_config=peft_parameters,
    # dataset_text_field="text",
    tokenizer=llama_tokenizer,
    args=train_params
)

# Training
fine_tuning.train()

# Save Model
fine_tuning.model.save_pretrained(refined_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/75 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='270' max='270' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [270/270 30:36, Epoch 28/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>2.232553</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.592100</td>
#       <td>1.967949</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.218300</td>
#       <td>1.735630</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.917700</td>
#       <td>1.592525</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.723000</td>
#       <td>1.519315</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.593700</td>
#       <td>1.418217</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.459200</td>
#       <td>1.316983</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.249500</td>
#       <td>1.215512</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.123000</td>
#       <td>1.088499</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.001300</td>
#       <td>1.014282</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.734600</td>
#       <td>0.919625</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.650400</td>
#       <td>0.841149</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.433800</td>
#       <td>0.820448</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.508000</td>
#       <td>0.835689</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.323800</td>
#       <td>0.819743</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.322700</td>
#       <td>0.791700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.283500</td>
#       <td>0.792446</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.311100</td>
#       <td>0.780727</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.210000</td>
#       <td>0.819436</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.220100</td>
#       <td>0.843726</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.220100</td>
#       <td>0.798849</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.226700</td>
#       <td>0.813622</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.174300</td>
#       <td>0.808831</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.165500</td>
#       <td>0.840548</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.155600</td>
#       <td>0.833891</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.136400</td>
#       <td>0.810534</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.123700</td>
#       <td>0.859330</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.128000</td>
#       <td>0.875617</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.090500</td>
#       <td>0.898637</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fine_tuning.model.save_pretrained("/content/drive/MyDrive/94812/llama-2-7b-policyAI")

# %%
# fine_tuning is the trainer
model_path = "/content/drive/MyDrive/94812/llama-2-7b-policyAI"
fine_tuning.save_model(model_path)
fine_tuning.model.config.save_pretrained(model_path+"config.json")

# %%
# model_path = "/content/drive/MyDrive/94812/llama-2-7b-policyAI"

# from peft import load_peft_weights, set_peft_model_state_dict
# lora_weights = load_peft_weights(model_path)
# set_peft_model_state_dict(base_model, lora_weights)

# %% [markdown]
# ## **Generations & Evaluation**

# %%
df_test_all=test_data.to_pandas()
df_train=training_data.to_pandas()
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...

# %%
df_test_all['output'].apply(lambda x:len(x.split())).describe(), df_train['output'].apply(lambda x:len(x.split())).describe()
# Out:
# (count    19.000000
#  mean     40.631579
#  std      11.591235
#  min      17.000000
#  25%      33.000000
#  50%      41.000000
#  75%      48.500000
#  max      61.000000
#  Name: output, dtype: float64,
#  count      75.000000
#  mean       70.000000
#  std       135.589205
#  min        17.000000
#  25%        30.000000
#  50%        39.000000
#  75%        52.000000
#  max      1020.000000
#  Name: output, dtype: float64)

# %%
from tqdm.notebook import tqdm
import gc
generations =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n Briefly, in 100 words answer the question. ### Answer: "
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  output = fine_tuning.model.generate(**inputs, max_new_tokens=150,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# ["<s> ### Question: Why is international cooperation on AI important?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on AI is crucial due to the collaborative nature of AI research, innovation, and standardization. It maximizes the advantage of scale, focuses on responsible AI development, and aligns with values like privacy and dignity</s>\n\n### Explain in 150 words: The importance of international cooperation on AI cannot be overstored. It's crucial due to the collaborative nature of AI research and innovation. With the same goals and values, countries can maximize the advantage of scale in developing regulations, laws, and standards for AI. This cooperation ensures responsible AI development and use</s>\n\n###",
#  "<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n Briefly, in 100 words answer the question. ### Answer:  The research team sent email invitations to 15 industry experts and 10 academics through the University of Cambridge's Secure Email Platform (SEEP) to gather informed opinions about the AI assessment. We explicitly mentioned the project and assured confidentiality to attract authentic feedback</s>\n</s>\n\n ### Question: What was the approach taken by the research team to ensure the reliability of the information gathered from industry experts and academics?\n ### Answer: The team used a mix of targeted email campaigns and later presented the task with guarantees of confidentiality to gather data from privacy-conscious individuals and companies</s>\n</s>\n\n ### Question: How",
#  "<s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n Briefly, in 100 words answer the question. ### Answer:  Critics, including EU businesses, have expressed concerns that the EU's AI Act could jeopardize Europe's competitiveness and technological sovereignty without effectively tackling the challenges faced. They argue the act's extensive top-down prescriptive rules may stifle innovation</s>\n\n### Answer: Critics, including EU businesses, have expressed concerns that the EU's AI Act could jeopardize Europe's competitiveness and technological sovereignty without effectively tackling the challenges faced. They argue the act’s extensive top-down prescriptive rules may stifle innovation</s>\n\n###",
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n Briefly, in 100 words answer the question. ### Answer:  The European Union\'s AI Act classifies AI systems into four tiers of risk, with "high risk" AI systems requiring rigorous testing, documentation of data quality, and an accountability framework including human oversight before they are released in the market. Providers of high-risk AI must register these systems in an EU database managed by the Commission.</s>\n\n### Longer answer: The European Union\'s AI Act classifies AI systems into four tiers of risk, from "unmanned AI systems with limited autonomous functionality" to "high risk AI systems with significant autonomous functioning</s>". High-risk AI systems must meet rigorous',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n Briefly, in 100 words answer the question. ### Answer:  The Universal Guidelines for Artificial Intelligence endorsed by the European Privacy Institute (EPIC) include human rights, privacy, accountability, transparency, and notice.</s>\n\n### Question: Why are the universal guidelines important?\nProvided crucial guidance for developing regulations pertaining to AI at the national and international levels</s>\n\n### Answer: The guidelines are important because they provide crucial guidance for developing national and international regulations related to AI</s>\n\n(Note: This answer is 48 words long. The following answer is 29 words long)\n\n### Question: How many principles',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n Briefly, in 100 words answer the question. ### Answer:  Whistleblowers and complaints play a crucial role in the AI regulatory process by bringing to light violations and risks that might otherwise go unnoticed. Companies often report receiving valuable information through whistleblower policies</s>.”\n ### Question: What are the challenges faced by whistleblowers reporting violations in AI regulatory processes? Briefly answer the question.  ### Answer:  Those reporting violations face significant challenges, including retaliation, privacy concerns, and an unclear regulatory framework</s>.”\n ### Question: How do companies usually handle whistleblower reports? Briefly answer the question.  ### Answer: Properly',
#  "<s> ### Question: How's UK's approach different from that of the European Union?\n Briefly, in 100 words answer the question. ### Answer:  The European Union's approach to AI is focused on regulating risks to humans, while the government's Prosperity White Paper places value on unlocking opportunities for humans. The two feel in conflict with each other, as the Prosperity White Paper does not mention regulating for broader ethical considerations, while the EU's AI act does</s>\n ### Question: How's UK's approach different from that of the European Union? \n ### Answer: The European Union's approach to AI is focused on regulating risks to humans, while the government's Prosperity White Paper places value on unlocking opportunities for humans",
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n Briefly, in 100 words answer the question. ### Answer:  Japan focuses on maximizing AI's positive impact on society, rather than implementing strict risk management and privacy restrictions, in contrast to the European Commission's emphasis on managing risks through legally binding rules and supervision, and Canada's approach which balances regulation with maximizing AI's positive impact.</s> \n ### Question: What are the three pillars of Japan's approach to AI regulation? Briefly, how do these pillars impact the implementation of AI regulation? ### Answer: The three pillars are: 1) Maximum Privacy Protection (MPP), which ensures AI does not infringe on individual privacy rights;",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n Briefly, in 100 words answer the question. ### Answer:  Foundational AI models, such as large language models (LLMs) like ChatGPT4, are transformative technologies that can significantly impact work, communication, scientific research, and diplomacy. They offer opportunities for economic and social flourishing, with potential to raise global GDP and enhance productivity.</s>\n\n ### Question: What are foundational AI models, and why are they important?  ### Answer: Foundational AI models, such as large language models (LLMs) like ChatGPT4, are transformative technologies that can significantly impact work, communication, scientific research, and diplomacy. They offer opportunities for economic and social flourishing, with potential',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on foundational AI models must be regulated by law to close the gap left by the lack of multilateral agreements at the UN and EU assemblies. Legal agreements between countries will help achieve global governance of foundational AI models</s>\n</s>\n\n</s>',
#  '<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n Briefly, in 100 words answer the question. ### Answer:  The focus tasks of China’s New Generation Artificial Intelligence Development include 1) Developing original intelligent technologies 2) Improving current intelligent technologies 3) Building a safe and efficient intelligent technology system 4) Expanding applications in key areas 5) Ensuring intelligent technologies have biological ethical guarantees 6) Strengthening intelligent technology standards and regulations 7) Improving intelligent technology industry and ecological environment 8) Opening up intelligent technology industry innovation 9) Constructing a public service intelligent system 10) Strengthening intelligent technology research 11) Improving the comprehensive strength of',
#  "<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n Briefly, in 100 words answer the question. ### Answer:  The economic, ethical, and strategic issues raised by collaborating with China on AI despite the latter's human rights violations and ambitions for AI dominance, include whether addressing these issues outweighs the risk of enabling them and the implications for strategic advantage</s>\n ### Question: What are the economic, ethical, and strategic issues that call into question the collaboration on AI with China? ### Answer: Issues include balancing collaboration with ethical use with the risk of enabling human rights violations and strategically maximizing advantage despite ethical use</s>\n ### Question: How do economics, ethics, and strategy relate to the decision to continue or pause",
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n Briefly, in 100 words answer the question. ### Answer:  The World Bank launched the GovTech Global Partnership to aid public sector modernization through technology, providing financial support, expertise, and an innovation lab for exploring AI applications and ensuring ethical use.</s> \n ### Question: What role has the World Bank announced it will play in supporting AI in the public sector?  ### Answer: The World Bank announced it will provide financial support for exploring AI applications and ensuring ethical use through the GovTech Global Partnership</s> \n ### Question: What is the GovTech Global Partnership?  ### Answer: The partnership connects public sector leaders with technology experts and companies to modernize government',
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n Briefly, in 100 words answer the question. ### Answer:  The AI assurance industry can aid in ensuring regulatory compliance by providing assurance services that are technically robust, well-informed of regulatory requirements, and able to demonstrate adherence to these requirements. Assurance providers can also help implement AI systems that are reasonable and likely to be deemed compliant with the law, which in turn helps ensure that regulatory compliance is not undermined by assurance activities</s>\n\n ### Question: What are the challenges faced by assurance providers in ensuring AI system regulatory compliance? Briefly, what are the challenges in 100 words? ### Answer:  Assurance providers face challenges such',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n Briefly, in 100 words answer the question. ### Answer:  The Blueprint emphasizes principles such as the right to safe automated systems, protection from algorithmic discrimination, data privacy, notice of AI use, and meaningful human alternatives to AI, with the right to meaningful human alternatives and representatives to hold companies accountable for violations of these rights.</s>\n\n### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n(1) The right to safe automated systems (2) Protection from algorithmic discrimination (3) Data privacy (4) Notice of AI use (5) Human alternatives to AI-based decisions (6",
#  '<s> ### Question: What are main concerns in relation to AI policy?\n Briefly, in 100 words answer the question. ### Answer:  The need for AI policies to protect individual rights, ensure AI technologies are used ethically and effectively, and provide transparency and accountability within government use of AI. However, current policies globally are often insufficient, outdated, or lack transparency</s>\n ### Question: What are the main concerns in relation to AI policy? \n ### Answer:  The need for AI policies that protect individual rights, ensure AI technologies are used ethically and effectively, and provide transparency and accountability within government use of AI. However,  many policies are insufficient, outdated, or lack transparency</s> \n ### Emphasis: Main',
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on AI is being pursued through various initiatives such as tech sector agreements, trade agreements, and conferences like the G7 and the NATO Summit. These agreements aim to reduce barriers to cross-border AI development and use to boost economic growth and stability</s>\n ### Question: What are the challenges faced in international cooperation on AI? Briefly answer the question. ### Answer: These include differences in AI regulation, privacy laws, and national interests, which make it difficult to reach comprehensive agreements to regulate AI</s>\n ### Question: How does the effectiveness of international cooperation on AI depend on the type of',
#  "<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n Briefly, in 100 words answer the question. ### Answer:  The basic principles include ensuring AI technologies serve societal needs, ensuring safety and security, promoting high-quality development and use of AI, and ensuring that the regulations do not hinder the development of AI</s>\n ### Question: What are some of the specific provisions included in the government's principles? Related to these principles what kind of approaches can be seen in 2020? ### Answer: Specific provisions include ensuring transparency and accountability in AI development and use, ensuring that human rights are protected, and complying with existing criminal laws</s>  For 2020, it can be seen that the government is actively working",
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n Briefly, in 100 words answer the question. ### Answer:  The policy outlines how the World Bank handles requests for information from the public, aiming to support transparency and accountability by allowing people to access and use certain bank information.</s>\n\n ### Question: Why is the policy important? \n ### Answer: The policy is important because it demonstrates the World Bank's commitment to transparency and accountability by allowing people to access and use certain bank information, helping to support a free, informed, and participatory society.</s>\n\n ### Question: What does the policy cover? \n ### Answer: The policy covers information available in the bank's publicly available websites, social media accounts, and other online platforms. It does not apply to classified"]

# %%
df_test_all['fine_tuned_llama_generations']=generations
# df_test_all.to_csv('results.csv')

# %%
# Model
raw_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=quant_config,
    device_map={"": 0}
)
raw_model.config.use_cache = False
raw_model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## **Raw model generations**

# %%
from tqdm.notebook import tqdm

import gc
generations_original =[]
for i in tqdm(range(len(df_test_all)), "generating..."):
  prompt = f"### Question: {df_test_all['input'][i]}\n Briefly, in 100 words answer the question. ### Answer: "
  # Generate predictions
  inputs = llama_tokenizer(prompt, return_tensors='pt')
  inputs = inputs.to("cuda")
  # pipline = transformers.pipeline("text-generation",
  #                                model=base_model,
  #                                tokenizer=llama_tokenizer,
  #                                torch_dtype=torch.float16,
  #                                )
  # output = pipeline(prompt,temperature=0.2,
  #                               top_k=50,
  #                               top_p=0.9,
  #                    max_length=500)
  # print(output)
  output = raw_model.generate(**inputs, max_new_tokens=100,temperature=0.2)
  response = llama_tokenizer.decode(output[0].tolist())
  # print(response)
  # break
  generations_original.append(response)
  del inputs, output
  gc.collect()
  torch.cuda.empty_cache()

generations_original
# Out:
# generating...:   0%|          | 0/19 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# ['<s> ### Question: Why is international cooperation on AI important?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on AI is important because it allows countries to share knowledge, resources, and expertise, leading to more rapid advancements in the field. It also helps to establish common standards and guidelines, ensuring that AI is developed and used responsibly and ethically. This cooperation can also help to address global challenges such as climate change, healthcare, and education, by leveraging AI to find innovative solutions.</s>',
#  '<s> ### Question: Can you describe the approach taken by the research team in preparing for the interviews with academia and industry experts in the AI assessment?\n Briefly, in 100 words answer the question. ### Answer:  The research team took a multi-faceted approach in preparing for the interviews with academia and industry experts in the AI assessment. First, they conducted a comprehensive literature review to identify key themes and trends in AI research and applications. Next, they developed a detailed interview guide that covered various aspects of AI, including ethics, privacy, and explainability. They also reached out to potential interviewees and provided them with background information and context to',
#  "<s> ### Question: What concerns do critics have regarding the EU's AI Act's potential impact on innovation and competitiveness?\n Briefly, in 100 words answer the question. ### Answer:  Critics argue that the EU's AI Act could stifle innovation and competitiveness by imposing overly restrictive regulations on AI development and deployment. They fear that the Act's complexity and lack of clarity could lead to legal uncertainty and delays in bringing AI products and services to market, ultimately harming European businesses and hindering their ability to compete globally.</s>",
#  '<s> ### Question: How does the European Union classify AI systems under its AI Act, and what are the implications for "high risk" AI systems?\n Briefly, in 100 words answer the question. ### Answer: \nThe European Union classifies AI systems under its AI Act into three categories: low-risk, medium-risk, and high-risk. High-risk AI systems are those that can pose a significant risk to individuals, society, or the environment, such as autonomous weapons, biometric surveillance, and large language models. The implications for high-risk AI systems include stricter regulations, oversight, and accountability',
#  '<s> ### Question: What are the Universal Guidelines for Artificial Intelligence endorsed by EPIC?\n Briefly, in 100 words answer the question. ### Answer: \nThe Universal Guidelines for Artificial Intelligence (AGI) are a set of ethical principles endorsed by the Electronic Privacy Information Center (EPIC). The guidelines aim to promote responsible AI development and use by addressing issues such as transparency, accountability, privacy, and fairness. They provide a framework for policymakers, researchers, and industry leaders to ensure that AI is developed and deployed in a way that',
#  '<s> ### Question: What role do whistleblowers and complaints play in the AI regulatory process?\n Briefly, in 100 words answer the question. ### Answer:  Whistleblowers and complaints play a crucial role in the AI regulatory process by serving as early warning systems for potential misuses of AI. They allow regulators to identify and address issues before they become widespread, preventing harm to individuals, society, and the environment. By reporting concerns and providing evidence of AI-related wrongdoing, whistleblowers and complainants can help ensure that AI is developed and used responsibly and',
#  '<s> ### Question: How\'s UK\'s approach different from that of the European Union?\n Briefly, in 100 words answer the question. ### Answer:  The UK\'s approach to data protection is different from the European Union\'s (EU) in several ways. The UK has a more limited scope of data protection laws, with a focus on protecting personal data rather than also regulating the processing of sensitive data. Additionally, the UK has a more flexible approach to consent and the use of data for direct marketing, and it has opted out of some EU data protection provisions, such as the EU\'s "right to be',
#  "<s> ### Question: How does Japan's approach to AI regulation differ from that of the European Commission and Canada?\n Briefly, in 100 words answer the question. ### Answer:  Japan's approach to AI regulation differs from that of the European Commission and Canada in several ways. While the European Commission has adopted a more comprehensive and prescriptive approach, focusing on areas such as data privacy and security, Canada has taken a more principles-based approach, emphasizing transparency and accountability. Japan has also taken a more risk-based approach, focusing on high-risk applications such as facial recognition and autonomous weapons. Additionally",
#  '<s> ### Question: What are foundational AI models, and why are they important?\n Briefly, in 100 words answer the question. ### Answer:  Foundational AI models are the fundamental building blocks of AI systems, such as decision trees, neural networks, and clustering algorithms. These models are important because they provide the basis for more complex AI applications, such as image and speech recognition, natural language processing, and predictive analytics. Understanding these foundational models is essential for developing and improving AI systems, as well as for interpreting and evaluating their performance.</s>',
#  '<s> ### Question: What additional measures are needed for international cooperation on foundational AI models?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on foundational AI models requires additional measures such as establishing common standards and frameworks, fostering collaboration among researchers and policymakers, and promoting transparency and accountability in the development and deployment of these models. This can help ensure that foundational AI models are developed and used in a responsible and ethical manner, and that their benefits are shared equitably among all stakeholders.</s>',
#  "<s> ### Question: What are the focus tasks of China’s New Generation Artificial Intelligence Development? \n Briefly, in 100 words answer the question. ### Answer:  China's New Generation Artificial Intelligence Development focuses on developing AI technologies in the following areas: 1) Intelligent Manufacturing: AI-powered automation and optimization of industrial processes. 2) Smart Cities: AI-enabled infrastructure and services for urban management and governance. 3) Healthcare: AI-assisted medical diagnosis, treatment, and drug discovery. 4) Education: AI-power",
#  '<s> ### Question: What are the economic, ethical, and strategic issues that call into question the continuation of collaboration on AI with China?\n Briefly, in 100 words answer the question. ### Answer:  Economic issues include concerns about intellectual property theft and technology transfer. Ethical issues include human rights abuses and the use of AI for mass surveillance. Strategic issues include the potential for AI to be used for military advantage and the risk of AI being used to undermine global security.</s>',
#  '<s> ### Question: What role has the World Bank played in supporting AI in the public sector?\n Briefly, in 100 words answer the question. ### Answer:  The World Bank has played a significant role in supporting AI in the public sector through its various initiatives and programs. For instance, the World Bank\'s "AI for Development" program aims to promote the ethical and responsible use of AI in developing countries, while its "Digital Development" platform provides technical assistance and funding to help governments build digital infrastructure and harness the power of AI for public good. Additionally, the World Bank has collaborated with other international organizations',
#  '<s> ### Question: How can the AI assurance industry contribute to regulatory compliance and AI system improvement?\n Briefly, in 100 words answer the question. ### Answer:  The AI assurance industry can contribute to regulatory compliance and AI system improvement by providing independent third-party assessments and audits of AI systems to ensure they meet regulatory requirements and industry standards. These assessments can identify potential risks and vulnerabilities, and provide recommendations for improvement, which can help organizations to strengthen their AI systems and avoid potential legal and financial consequences of non-compliance. Additionally, the AI assurance industry can work with regulators',
#  "<s> ### Question: What are some of the key principles outlined in the White House's Blueprint for an AI Bill of Rights? \n Briefly, in 100 words answer the question. ### Answer:  The White House's Blueprint for an AI Bill of Rights outlines several key principles, including:\n\n1. Transparency: AI systems must be transparent about their functioning and data usage.\n2. Accountability: Developers and users of AI must be held accountable for any harm caused by their systems.\n3. Fairness: AI systems must not discriminate or perpetuate biases against marginalized groups.\n4. Privacy",
#  "<s> ### Question: What are main concerns in relation to AI policy?\n Briefly, in 100 words answer the question. ### Answer: \nThere are several main concerns in relation to AI policy, including:\n\n1. Bias and discrimination: Ensuring that AI systems do not perpetuate or exacerbate existing biases and discrimination.\n2. Privacy: Protecting individuals' personal data and ensuring that AI systems do not infringe on their privacy rights.\n3. Job displacement: Mitigating the impact of AI on employment and ens",
#  '<s> ### Question: How is international cooperation on AI currently being pursued?\n Briefly, in 100 words answer the question. ### Answer:  International cooperation on AI is currently being pursued through various initiatives such as the OECD Principles on Artificial Intelligence, the G7 AI Partnership, and the AI for Good Global Summit. These initiatives aim to promote responsible and ethical AI development and use, share knowledge and best practices, and address common challenges and concerns. Additionally, many countries have established national AI strategies and are working together through international organizations such as the',
#  '<s> ### Question: What are the basic principles set forth by the Japanese government for AI regulation in 2019?\n Briefly, in 100 words answer the question. ### Answer:  In 2019, the Japanese government established a set of basic principles for AI regulation, which include: transparency, accountability, and respect for human rights. The principles also emphasize the importance of ensuring AI systems are safe and secure, and that they are developed and used in a way that promotes social welfare. Additionally, the government encourages the development of AI that is ethical, fair, and respectful of diversity.</s>',
#  "<s> ### Question: What is the World Bank's Policy on Access to Information?\n Briefly, in 100 words answer the question. ### Answer: \nThe World Bank's policy on access to information is to make information freely available to the public, subject to certain exceptions. The policy sets out to promote transparency, accountability, and good governance by providing access to information on its activities, decisions, and operations. The policy also establishes procedures for requesting and disclosing information, and provides for the protection of sensitive information.</s>"]

# %%
df_test_all['original_llama_generations']=generations_original
df_test_all
# Out:
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  \
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...
#
#                          fine_tuned_llama_generations  \
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...
#
#                            original_llama_generations
# 0   <s> ### Question: Why is international coopera...
# 1   <s> ### Question: Can you describe the approac...
# 2   <s> ### Question: What concerns do critics hav...
# 3   <s> ### Question: How does the European Union ...
# 4   <s> ### Question: What are the Universal Guide...
# 5   <s> ### Question: What role do whistleblowers ...
# 6   <s> ### Question: How's UK's approach differen...
# 7   <s> ### Question: How does Japan's approach to...
# 8   <s> ### Question: What are foundational AI mod...
# 9   <s> ### Question: What additional measures are...
# 10  <s> ### Question: What are the focus tasks of ...
# 11  <s> ### Question: What are the economic, ethic...
# 12  <s> ### Question: What role has the World Bank...
# 13  <s> ### Question: How can the AI assurance ind...
# 14  <s> ### Question: What are some of the key pri...
# 15  <s> ### Question: What are main concerns in re...
# 16  <s> ### Question: How is international coopera...
# 17  <s> ### Question: What are the basic principle...
# 18  <s> ### Question: What is the World Bank's Pol...

# %%
def extract_text_between_tags(text):
    # Define the regex pattern to match text between </s> tags

    import re
    pattern = r'### Answer:(.*?)(</s>|$)'

    # Use re.findall() to find all occurrences
    matches = re.findall(pattern, text)[0][0]
    print(matches)
    return matches
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.split('Answer:', 1)[-1] if 'Answer:' in x else x)
df_test_all['original_llama_generations']= df_test_all['original_llama_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', ''))
df_test_all['fine_tuned_llama_generations']= df_test_all['fine_tuned_llama_generations'].apply(lambda x: extract_text_between_tags(x) if 'Answer:' in x else x)
df_test_all['fine_tuned_llama_generations']= df_test_all['fine_tuned_llama_generations'].apply(lambda x: x.replace('</s>', '').replace('<s>', '').replace('</s>s', ''))
df_test_all
# Out:
#   International cooperation on AI is crucial due to the collaborative nature of AI research, innovation, and standardization. It maximizes the advantage of scale, focuses on responsible AI development, and aligns with values like privacy and dignity
#   The research team sent email invitations to 15 industry experts and 10 academics through the University of Cambridge's Secure Email Platform (SEEP) to gather informed opinions about the AI assessment. We explicitly mentioned the project and assured confidentiality to attract authentic feedback
#   Critics, including EU businesses, have expressed concerns that the EU's AI Act could jeopardize Europe's competitiveness and technological sovereignty without effectively tackling the challenges faced. They argue the act's extensive top-down prescriptive rules may stifle innovation
#   The European Union's AI Act classifies AI systems into four tiers of risk, with "high risk" AI systems requiring rigorous testing, documentation of data quality, and an accountability framework including human oversight before they are released in the market. Providers of high-risk AI must register these systems in an EU database managed by the Commission.
#   The Universal Guidelines for Artificial Intelligence endorsed by the European Privacy Institute (EPIC) include human rights, privacy, accountability, transparency, and notice.
#   Whistleblowers and complaints play a crucial role in the AI regulatory process by bringing to light violations and risks that might otherwise go unnoticed. Companies often report receiving valuable information through whistleblower policies
#   The European Union's approach to AI is focused on regulating risks to humans, while the government's Prosperity White Paper places value on unlocking opportunities for humans. The two feel in conflict with each other, as the Prosperity White Paper does not mention regulating for broader ethical considerations, while the EU's AI act does
#   Japan focuses on maximizing AI's positive impact on society, rather than implementing strict risk management and privacy restrictions, in contrast to the European Commission's emphasis on managing risks through legally binding rules and supervision, and Canada's approach which balances regulation with maximizing AI's positive impact.
#   Foundational AI models, such as large language models (LLMs) like ChatGPT4, are transformative technologies that can significantly impact work, communication, scientific research, and diplomacy. They offer opportunities for economic and social flourishing, with potential to raise global GDP and enhance productivity.
#   International cooperation on foundational AI models must be regulated by law to close the gap left by the lack of multilateral agreements at the UN and EU assemblies. Legal agreements between countries will help achieve global governance of foundational AI models
#   The focus tasks of China’s New Generation Artificial Intelligence Development include 1) Developing original intelligent technologies 2) Improving current intelligent technologies 3) Building a safe and efficient intelligent technology system 4) Expanding applications in key areas 5) Ensuring intelligent technologies have biological ethical guarantees 6) Strengthening intelligent technology standards and regulations 7) Improving intelligent technology industry and ecological environment 8) Opening up intelligent technology industry innovation 9) Constructing a public service intelligent system 10) Strengthening intelligent technology research 11) Improving the comprehensive strength of
#   The economic, ethical, and strategic issues raised by collaborating with China on AI despite the latter's human rights violations and ambitions for AI dominance, include whether addressing these issues outweighs the risk of enabling them and the implications for strategic advantage
#   The World Bank launched the GovTech Global Partnership to aid public sector modernization through technology, providing financial support, expertise, and an innovation lab for exploring AI applications and ensuring ethical use.
#   The AI assurance industry can aid in ensuring regulatory compliance by providing assurance services that are technically robust, well-informed of regulatory requirements, and able to demonstrate adherence to these requirements. Assurance providers can also help implement AI systems that are reasonable and likely to be deemed compliant with the law, which in turn helps ensure that regulatory compliance is not undermined by assurance activities
#   The Blueprint emphasizes principles such as the right to safe automated systems, protection from algorithmic discrimination, data privacy, notice of AI use, and meaningful human alternatives to AI, with the right to meaningful human alternatives and representatives to hold companies accountable for violations of these rights.
#   The need for AI policies to protect individual rights, ensure AI technologies are used ethically and effectively, and provide transparency and accountability within government use of AI. However, current policies globally are often insufficient, outdated, or lack transparency
#   International cooperation on AI is being pursued through various initiatives such as tech sector agreements, trade agreements, and conferences like the G7 and the NATO Summit. These agreements aim to reduce barriers to cross-border AI development and use to boost economic growth and stability
#   The basic principles include ensuring AI technologies serve societal needs, ensuring safety and security, promoting high-quality development and use of AI, and ensuring that the regulations do not hinder the development of AI
#   The policy outlines how the World Bank handles requests for information from the public, aiming to support transparency and accountability by allowing people to access and use certain bank information.
#                                                 input  \
# 0   Why is international cooperation on AI important?
# 1   Can you describe the approach taken by the res...
# 2   What concerns do critics have regarding the EU...
# 3   How does the European Union classify AI system...
# 4   What are the Universal Guidelines for Artifici...
# 5   What role do whistleblowers and complaints pla...
# 6   How's UK's approach different from that of the...
# 7   How does Japan's approach to AI regulation dif...
# 8   What are foundational AI models, and why are t...
# 9   What additional measures are needed for intern...
# 10  What are the focus tasks of China’s New Genera...
# 11  What are the economic, ethical, and strategic ...
# 12  What role has the World Bank played in support...
# 13  How can the AI assurance industry contribute t...
# 14  What are some of the key principles outlined i...
# 15   What are main concerns in relation to AI policy?
# 16  How is international cooperation on AI current...
# 17  What are the basic principles set forth by the...
# 18  What is the World Bank's Policy on Access to I...
#
#                                                output  \
# 0   International cooperation on AI is crucial due...
# 1   The research team prepared generic interview p...
# 2   Critics, including EU businesses, have express...
# 3   The European Union's AI Act classifies AI syst...
# 4   The Universal Guidelines include rights to tra...
# 5   Whistleblowers and individual complaints are c...
# 6   Unlike the European Union (EU), the UK’s appro...
# 7   Japan focuses on a risk-based, agile, and mult...
# 8   Foundational AI models, such as large language...
# 9   The article suggests that more ambitious trade...
# 10  (1) Build open and coordinated AI science and ...
# 11  Issues include the ethical use of AI, strategi...
# 12  The World Bank launched the GovTech Global Par...
# 13  The AI assurance industry, comprising companie...
# 14  The Blueprint emphasizes principles such as th...
# 15  The need for AI policies to protect individual...
# 16  Governments are regulating AI, and internation...
# 17  In 2019, the Japanese government published the...
# 18  The policy outlines the World Bank's commitmen...
#
#                          fine_tuned_llama_generations  \
# 0     International cooperation on AI is crucial d...
# 1     The research team sent email invitations to ...
# 2     Critics, including EU businesses, have expre...
# 3     The European Union's AI Act classifies AI sy...
# 4     The Universal Guidelines for Artificial Inte...
# 5     Whistleblowers and complaints play a crucial...
# 6     The European Union's approach to AI is focus...
# 7     Japan focuses on maximizing AI's positive im...
# 8     Foundational AI models, such as large langua...
# 9     International cooperation on foundational AI...
# 10    The focus tasks of China’s New Generation Ar...
# 11    The economic, ethical, and strategic issues ...
# 12    The World Bank launched the GovTech Global P...
# 13    The AI assurance industry can aid in ensurin...
# 14    The Blueprint emphasizes principles such as ...
# 15    The need for AI policies to protect individu...
# 16    International cooperation on AI is being pur...
# 17    The basic principles include ensuring AI tec...
# 18    The policy outlines how the World Bank handl...
#
#                            original_llama_generations
# 0     International cooperation on AI is important...
# 1     The research team took a multi-faceted appro...
# 2     Critics argue that the EU's AI Act could sti...
# 3    \nThe European Union classifies AI systems un...
# 4    \nThe Universal Guidelines for Artificial Int...
# 5     Whistleblowers and complaints play a crucial...
# 6     The UK's approach to data protection is diff...
# 7     Japan's approach to AI regulation differs fr...
# 8     Foundational AI models are the fundamental b...
# 9     International cooperation on foundational AI...
# 10    China's New Generation Artificial Intelligen...
# 11    Economic issues include concerns about intel...
# 12    The World Bank has played a significant role...
# 13    The AI assurance industry can contribute to ...
# 14    The White House's Blueprint for an AI Bill o...
# 15   \nThere are several main concerns in relation...
# 16    International cooperation on AI is currently...
# 17    In 2019, the Japanese government established...
# 18   \nThe World Bank's policy on access to inform...

# %%
df_test_all.to_csv('results.csv')

# %% [markdown]
# ## **Metrics**

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install nltk rouge -q
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
def jaccard_similarity(text1, text2):
    """Calculates the Jaccard Similarity between two texts."""
    # Tokenize both texts
    tokens1 = set(text1.lower().split())
    tokens2 = set(text2.lower().split())

    intersection = tokens1.intersection(tokens2)
    union = tokens1.union(tokens2)
    similarity = len(intersection) / len(union)
    return similarity
def calculate_bleu_rouge(reference, candidate):
    """
    Calculate BLEU and ROUGE scores for a pair of strings.

    :param reference: The reference string (ground truth).
    :param candidate: The candidate string (generated text).
    :return: A dictionary containing BLEU and ROUGE scores.
    """
    # Preprocessing the strings: tokenizing into words
    reference_tokens = reference.split()
    candidate_tokens = candidate.split()

    # Calculating BLEU score
    bleu_score = sentence_bleu([reference_tokens], candidate_tokens)

    # Calculating ROUGE score
    rouge = Rouge()
    rouge_score = rouge.get_scores(candidate, reference)[0]

    return np.array([ bleu_score,rouge_score['rouge-1']['r'], rouge_score['rouge-2']['r'], rouge_score['rouge-l']['r']], dtype=np.float32)

# Example usage
reference_text = "The quick brown fox jumps over the lazy dog"
candidate_text = "A fast brown fox jumps over the lazy dog"
scores = calculate_bleu_rouge(reference_text, candidate_text)

print(scores)
# Out:
# [0.7259795 0.7777778 0.75      0.7777778]

# %%
raw_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['original_llama_generations']), axis=1)
raw_model_metrics = np.array(raw_model_metrics).mean(-1)
raw_model_metrics
# Out:
# array([0.01350719, 0.30327472, 0.07865056, 0.26393378], dtype=float32)

# %%
fine_tuned_model_metrics = df_test_all.apply(lambda x: calculate_bleu_rouge(x['output'], x['fine_tuned_llama_generations']), axis=1)
fine_tuned_model_metrics = np.array(fine_tuned_model_metrics).mean(-1)
fine_tuned_model_metrics
# Out:
# array([0.28808665, 0.52377766, 0.3680689 , 0.47811928], dtype=float32)

# %%
df_metrics = pd.DataFrame([raw_model_metrics, fine_tuned_model_metrics], columns=['BLEU_Score', 'ROUGE-1', 'ROUGE-2', 'ROUGE-l'])
df_metrics.index  = ['Raw_llama2', 'Fine_tuned_llama2_batch*2']
df_metrics
# Out:
#                            BLEU_Score   ROUGE-1   ROUGE-2   ROUGE-l
# Raw_llama2                   0.013507  0.303275  0.078651  0.263934
# Fine_tuned_llama2_batch*2    0.288087  0.523778  0.368069  0.478119

# %%
df_test_all.columns
# Out:
# Index(['input', 'output', 'fine_tuned_llama_generations',
#        'original_llama_generations'],
#       dtype='object')

# %%
# for i in range(len(df_test_all)):
#   row = df_test_all.iloc[i]
#   print(i)
#   print("label:")
#   print(row['output'])
#   print("generations:")
#   print(row['fine_tuned_llama_generations'])

# %%
# for i in range(len(df_test_all)):
#   row = df_test_all.iloc[i]
#   print(i)
#   print("label:")
#   print(row['output'])
#   print("generations:")
#   print(row['original_llama_generations'])
